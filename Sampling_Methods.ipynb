# %% [markdown]
# # importing files

# %%
import pandas as pd
import numpy as np
import random

# %% [markdown]
# # random data generation

# %%
data = {
    "total_matches": np.random.randint(20,100,100),
    "centuries": np.random.randint(20,100,100),
    "half_centuries": np.random.randint(20,100,100),
    "highest_score": np.random.randint(20,100,100),
    "total_runs": np.random.randint(20,100,100),
    "strike_rate": np.random.randint(20,100,100),
}
df = pd.DataFrame(data)

# %% [markdown]
# ## mean

# %%
original_mean = df.mean()
print(original_mean)
# Out:
# total_matches     61.25
# centuries         58.16
# half_centuries    61.28
# highest_score     58.02
# total_runs        59.13
# strike_rate       63.07
# dtype: float64

# %% [markdown]
# ## srs

# %%
srs = df.sample(3,random_state = 1)
srs_mean = srs.mean()
srs_mean
srs_difference = original_mean - srs_mean
srs_difference
# Out:
# total_matches     -6.416667
# centuries          7.493333
# half_centuries     0.613333
# highest_score     12.020000
# total_runs        -2.870000
# strike_rate       12.403333
# dtype: float64

# %% [markdown]
# # ssm

# %%
ssm = df[df["total_matches"]>25].sample(5,random_state = 1)
ssm
ssm_mean = ssm.mean()
ssm_mean
ssm_difference = ssm_mean - original_mean
ssm_difference
# Out:
# total_matches    -10.65
# centuries         21.04
# half_centuries     0.92
# highest_score      0.78
# total_runs       -13.33
# strike_rate        9.13
# dtype: float64
